# %% [markdown]
# # 📓 Working with Numpy Exercise Notebook
# # 🎯 Objective
# This notebook is designed to help you practice some important intermediate Python concepts. You will solve tasks using:
#
#  - Creating a Numpy array
#
#  - Slicing in Numpy
#
#  - Indexing in Numpy
#
#  - Reshaping in numpy
#
#  - Arithmetic Operation in numpy
#
# Each question is followed by a code cell for your answer. Use the hints to guide your thought process, but avoid looking up direct examples unless you are completely stuck.

# %% [markdown]
# #### Creating Numpy array

# %%
# Q1: Create a 3x3 NumPy array filled entirely with ones.
# Hint: Use a NumPy function that creates arrays filled with the same number.

# 👇 Your code starts here

# %%
# Q2: Generate a 4x4 identity matrix using NumPy.
# Hint: The identity matrix has 1s on the diagonal and 0s elsewhere.

# 👇 Your code starts here

# %%
# Q3: Create a 2x5 NumPy array filled entirely with zeros.
# Hint: Use a NumPy function that initializes arrays with zeros.

# 👇 Your code starts here

# %%
# Q4: Create a 1D NumPy array with 5 random numbers between 0 and 1.
# Hint: Use a NumPy function that generates random floats in [0.0, 1.0).

# 👇 Your code starts here

# %%
# Q5: Create a 3x2 NumPy array with random integers between 10 and 50 (inclusive of 10, exclusive of 50).
# Hint: Use a function that allows you to set the range and shape of the random integers.

# 👇 Your code starts here

# %% [markdown]
# #### Slicing, Indexing and Reshaping

# %%
# Q1: Create a NumPy array with numbers from 0 to 9.
# Then, print the element at index 3.

# Hint: Remember that array indices start at 0.

# 👇 Your code starts here

# %%
# Q2: Using the array from Q1, slice and print the elements from index 2 to 5 (inclusive of 2, exclusive of 6).
# Hint: Use array slicing syntax to get part of the array.

# 👇 Your code starts here

# %%
# Q3: Reshape the array from Q1 into a 2 rows by 5 columns matrix.
# Hint: Use the reshape() method.

# 👇 Your code starts here

# %% [markdown]
# #### Arithmetic Operation

# %%
# Q1: Create a NumPy array of these numbers: [4, 7, 2, 9, 5]
# Calculate and print the mean (average) of the array.

# Hint: Use the numpy function for mean.

# 👇 Your code starts here

# %%
# Q2: Using the same array, calculate and print the sum of all numbers.
# Hint: Use the numpy function that adds all elements.

# 👇 Your code starts here
